# %% [markdown]
# # Menghapus (drop) missing values (`NaN`)

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 2.2.3
# NumPy version: 2.1.3

# %% [markdown]
# ## Persiapan Data Frame

# %%
# Buat DataFrame acak dengan NaN
np.random.seed(42)
df = pd.DataFrame(np.random.randn(10, 4), columns=list("ABCD"))

# Sisipkan beberapa NaN secara acak
for _ in range(10):
    i = np.random.randint(0, 10)
    j = np.random.randint(0, 4)
    df.iat[i, j] = np.nan

df.reset_index(inplace=True)
print(df.head())
# Out:
#    index         A         B         C         D
# 0      0  0.496714 -0.138264  0.647689  1.523030
# 1      1 -0.234153       NaN       NaN  0.767435
# 2      2 -0.469474  0.542560 -0.463418 -0.465730
# 3      3  0.241962       NaN -1.724918 -0.562288
# 4      4 -1.012831  0.314247 -0.908024       NaN

# %%
df = df.rename(columns = {'index': 'Z'})
df.head()
# Out:
#    Z         A         B         C         D
# 0  0  0.496714 -0.138264  0.647689  1.523030
# 1  1 -0.234153       NaN       NaN  0.767435
# 2  2 -0.469474  0.542560 -0.463418 -0.465730
# 3  3  0.241962       NaN -1.724918 -0.562288
# 4  4 -1.012831  0.314247 -0.908024       NaN

# %%
df_backup = df.copy(deep=True)

# %% [markdown]
# ## Menghapus (drop) setiap kolom yang mengandung missing values

# %%
df = df.dropna(axis='columns')
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# ## Menghapus (drop) setiap baris yang mengandung missing values

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#    Z         A         B         C         D
# 0  0  0.496714 -0.138264  0.647689  1.523030
# 2  2 -0.469474  0.542560 -0.463418 -0.465730
# 5  5  1.465649 -0.225776  0.067528 -1.424748

# %% [markdown]
# ## Persentase missing values untuk tiap kolom

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.0
# A    0.2
# B    0.4
# C    0.1
# D    0.2
# dtype: float64

# %% [markdown]
# ## Menghapus (drop) setiap kolom yang mengandung missing values berdasarkan threshold

# %%
threshold = len(df) * 0.9
df = df.dropna(thresh=threshold, axis='columns')
df.head()
# Out:
#    Z         C
# 0  0  0.647689
# 1  1       NaN
# 2  2 -0.463418
# 3  3 -1.724918
# 4  4 -0.908024
