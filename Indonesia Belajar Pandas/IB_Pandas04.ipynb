# %%
import pandas as pd
import numpy as np

n_rows = 5
n_cols = 2
cols = ['bil_pecahan', 'bil_bulat']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)
df = df.astype({'bil_pecahan': 'float'})

# Ganti baris yang error dengan ini:
# df.index = pd.util.testing.makeDataIndex(n_rows, freq='h')
# menjadi:
df.index = pd.date_range(start='2025-01-01', periods=n_rows, freq='h')

df = df.reset_index()
df['text'] = list('ABCDE')

df
# Out:
#                 index  bil_pecahan  bil_bulat text
# 0 2025-01-01 00:00:00         13.0          5    A
# 1 2025-01-01 01:00:00         18.0          8    B
# 2 2025-01-01 02:00:00          7.0         12    C
# 3 2025-01-01 03:00:00         13.0          6    D
# 4 2025-01-01 04:00:00         19.0         17    E

# %%
df.dtypes
# Out:
# index          datetime64[ns]
# bil_pecahan           float64
# bil_bulat               int64
# text                   object
# dtype: object

# %%
df.select_dtypes(include='number')
# Out:
#    bil_pecahan  bil_bulat
# 0         13.0          5
# 1         18.0          8
# 2          7.0         12
# 3         13.0          6
# 4         19.0         17

# %%
df.select_dtypes(include='datetime')
# Out:
#                 index
# 0 2025-01-01 00:00:00
# 1 2025-01-01 01:00:00
# 2 2025-01-01 02:00:00
# 3 2025-01-01 03:00:00
# 4 2025-01-01 04:00:00

# %%
df.select_dtypes(include='int')
# Out:
#    bil_bulat
# 0          5
# 1          8
# 2         12
# 3          6
# 4         17

# %%
df.select_dtypes(include=['object','int'])
# Out:
#    bil_bulat text
# 0          5    A
# 1          8    B
# 2         12    C
# 3          6    D
# 4         17    E
